# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# Running cells with 'ren-blue (Python 3.13.11)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/git/ren_blue/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
